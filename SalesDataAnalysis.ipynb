# %% [markdown]
# <H1 style="color:SlateBlue;"> Grip: The Spark Foundation </H1>

# %% [markdown]
# <b> Data Science and Business Analytics Internship </b>

# %% [markdown]
# <B> Task Three: Exploratory Data Analysis - Retail </B>

# %% [markdown]
# <b> Submitted by Sagar Das </b>

# %% [markdown]
# <H3 style="color:SlateBlue;"> Trying to find weak areas of business using Exploratory Data Analysis:</H3>

# %% [markdown]
# <p><b> Here we are taking the role of Business manager and trying to find weak areas of our business where we can work more to make more profit. We will perform exploratory data analysis on the data we have, observe our results and draw conclusion from that.</b> </p>

# %% [markdown]
# <h2 style="color:purple;"><B>Loading, Viewing, and Cleaning the Dataset</B> </h2>

# %% [markdown]
# <H4 style="color:Crimson;"><li> Loading Required Python Libraries</li> </H4>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
print("Libraries loaded!")
# Out:
# Libraries loaded!

# %% [markdown]
# <h4 style="color:Crimson;"><li> Now Let us Read and Explore the Dataset</li> </h4>

# %%
data = pd.read_csv(r"C:\Users\sagar\Documents\SampleSuperstore.csv")
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %% [markdown]
# <b> So, the dataset has 9994 rows and 13 columns. </b>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# <B> So we don't have any null values. We can see that data type of Postal codes should be object.</B>

# %%
data["Postal Code"]=data["Postal Code"].astype(str)
data["Postal Code"].dtype
# Out:
# dtype('O')

# %%
data.duplicated().sum()
# Out:
# 17

# %% [markdown]
# <p><B> So, we have 17 duplicated rows.</B> </p>

# %% [markdown]
# <h4 style="color:crimson;"> <li> <B>Dropping Duplicated rows</B></li> </h4>

# %%
data.drop_duplicates(inplace= True)

# %% [markdown]
# <b> Let us verify that duplicated rows are removed or not.</b>

# %%
data.shape
# Out:
# (9977, 13)

# %% [markdown]
# <b> Here are top frequencies for variables of our data. </b>

# %%
for column in data:
    if data[column].dtype == "object" and column == "City" or column ==  "State" or column ==  "Sub-Category" or column == "Postal Code":
        print(data[column].value_counts().to_frame().iloc[0:5,:])
        print("")
        print("Number of unique Values in", column ,":",len(data[column].unique()))
        print("")
    elif data[column].dtype == "object":
        print("")
        print(data[column].value_counts().to_frame())
        print("")
        print("Number of unique Values in", column ,":",len(data[column].unique()))
    else:
        pass
# Out:
#                 Ship Mode
# Standard Class       5955
# Second Class         1943
# First Class          1537
# Same Day              542
#
# Number of unique Values in Ship Mode : 4
#
#              Segment
# Consumer        5183
# Corporate       3015
# Home Office     1779
#
# Number of unique Values in Segment : 3
#
#                Country
# United States     9977
#
# Number of unique Values in Country : 1
#                City
# New York City   914
# Los Angeles     746
# Philadelphia    536
# San Francisco   506
# Seattle         424
#
# Number of unique Values in City : 531
#
#               State
# California     1996
# New York       1127
# Texas           983
# Pennsylvania    586
# Washington      502
#
# Number of unique Values in State : 49
#
#        Postal Code
# 10035          263
# 10024          230
# 10009          229
# 94122          199
# 10011          192
#
# Number of unique Values in Postal Code : 631
#
#
#          Region
# West       3193
# East       2845
# Central    2319
# South      1620
#
# Number of unique Values in Region : 4
#
#                  Category
# Office Supplies      6012
# Furniture            2118
# Technology           1847
#
# Number of unique Values in Category : 3
#              Sub-Category
# Binders              1522
# Paper                1359
# Furnishings           956
# Phones                889
# Storage               846
#
# Number of unique Values in Sub-Category : 17

# %% [markdown]
# <b> From the above frequency tables we can see that all the observations are from United States so we can omit that column from our dataset. Also we would like to remove postal codes from our data as we will work on locations based on city, state and region. </b>

# %% [markdown]
# <h4 style="color:crimson;"> <li> <B>Dropping unnecessary columns</B></li> </h4>

# %%
data.drop(["Country","Postal Code"],axis=1,inplace= True)

# %%
data.head()
# Out:
#         Ship Mode    Segment             City       State Region  \
# 0    Second Class   Consumer        Henderson    Kentucky  South
# 1    Second Class   Consumer        Henderson    Kentucky  South
# 2    Second Class  Corporate      Los Angeles  California   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# <h2 style="color:purple;"><B>Exploratory Data Analysis</B> </h2>

# %% [markdown]
# <h4 style="color:crimson;"> <li> <B>Some Statistical Measures on Our Data</B></li> </h4>

# %%
data.describe(include="all")
# Out:
#              Ship Mode   Segment           City       State Region  \
# count             9977      9977           9977        9977   9977
# unique               4         3            531          49      4
# top     Standard Class  Consumer  New York City  California   West
# freq              5955      5183            914        1996   3193
# mean               NaN       NaN            NaN         NaN    NaN
# std                NaN       NaN            NaN         NaN    NaN
# min                NaN       NaN            NaN         NaN    NaN
# 25%                NaN       NaN            NaN         NaN    NaN
# 50%                NaN       NaN            NaN         NaN    NaN
# 75%                NaN       NaN            NaN         NaN    NaN
# max                NaN       NaN            NaN         NaN    NaN
#
#                Category Sub-Category         Sales     Quantity     Discount  \
# count              9977         9977   9977.000000  9977.000000  9977.000000
# unique                3           17           NaN          NaN          NaN
# top     Office Supplies      Binders           NaN          NaN          NaN
# freq               6012         1522           NaN          NaN          NaN
# mean                NaN          NaN    230.148902     3.790719     0.156278
# std                 NaN          NaN    623.721409     2.226657     0.206455
# min                 NaN          NaN      0.444000     1.000000     0.000000
# 25%                 NaN          NaN     17.300000     2.000000     0.000000
# 50%                 NaN          NaN     54.816000     3.000000     0.200000
# 75%                 NaN          NaN    209.970000     5.000000     0.200000
# max                 NaN          NaN  22638.480000    14.000000     0.800000
#
#             Profit
# count   9977.00000
# unique         NaN
# top            NaN
# freq           NaN
# mean      28.69013
# std      234.45784
# min    -6599.97800
# 25%        1.72620
# 50%        8.67100
# 75%       29.37200
# max     8399.97600

# %%
data.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200722 -0.028311  0.479067
# Quantity  0.200722  1.000000  0.008678  0.066211
# Discount -0.028311  0.008678  1.000000 -0.219662
# Profit    0.479067  0.066211 -0.219662  1.000000

# %%
sns.heatmap(data.corr(),annot=True, cmap='RdYlGn')
plt.show()

# %% [markdown]
# <b> Correlation table and heatmap for our data. Interesting that Discount has bad correlation with both Sales and Profit. </b>

# %% [markdown]
# <h4 style="color:crimson;"> <li> <B>Order Count plots for different variables</B></li> </h4>

# %%
for column in data:
    if data[column].dtype == "object" and len(data[column].unique())<=5:
        data[column].value_counts().to_frame().plot(kind='pie', subplots=True, title=f"{column} wise order count disribution",autopct='%1.2f%%',shadow=True,figsize=(6, 6))
    elif data[column].dtype == "object" or column=="Quantity" and len(data[column].unique()) > 5:
        data[column].value_counts().to_frame().iloc[0:19,:].plot(kind='bar',title=f"{column} wise order count disribution (first 20)",figsize=(9, 6),color='crimson',ylabel="Order Count")
    else:
        pass
plt.show()

# %%
sns.countplot(x="Region",hue="Category", data=data)
plt.ylabel("Order Count")
plt.title("Category and Region wise order count distribution")
plt.show()

# %% [markdown]
# <b><li> From the above analysis we can see that Most of the Orders are Standard Class (59.7%).</li><br><li> Most of the orders are by consumers (54%) and least are from Home offices (18%).</li><br><li> Most of the orders are from New York City (914), followed by Los Angeles (746), Philadelphia, San Francisco, Seattle et cetera.</li><br><li>Statewise most of the orders are from California (1996), followed by New York (1127), Texas (983), Pensylvania, Washington et cetera.</li><br><li> Most orders are from West US and least from South US. So we are not that strong on Southern part of our country.</li><br><li> Most orders are for Office Suplies (60.3%), followed by Furniture (21.2%), and Technology (18.5%). We should work on our Technology and Furniture section to make them stronger.</li><br><li> Most orders are for Binders, Paper, Furnishings, Phones, Storage et cetera.</li><br><li>Most orders are for two or three products.</li>

# %% [markdown]
# <h4 style="color:crimson;"> <li> <B>Regionwise Sales and Profit Data Analysis</B></li> </h4>

# %%
gr_1 = data[["Region","Sales"]]
data_gr1 = gr_1.groupby(gr_1["Region"],as_index=True).sum()

gr_2 = data[["Region","Profit"]]
data_gr2 = gr_2.groupby(gr_2["Region"],as_index=True).sum()

data_c3 = pd.concat([data_gr1,data_gr2["Profit"]],axis=1)
data_c3
# Out:
#                Sales       Profit
# Region
# Central  500782.8528   39655.8752
# East     678435.1960   91506.3092
# South    391721.9050   46749.4303
# West     725255.6365  108329.8079

# %%
data_c3.plot(kind='bar',figsize=(16, 6),ylabel="US Dollars")

plt.show()

# %% [markdown]
# <B>From above vizualizations we can see that our Sales are least in Southern US followed by Central US. And by profit we are weakest in Central US followed by Southern US. So let us narrow down to South and Central US and work on these regions. </B>

# %% [markdown]
# <h4 style="color:crimson;"> <li> <B>Statewise Sales and Profit Data Analysis (US-South)</B></li> </h4>

# %%
result_df1 = data[(data["Region"]=="South")]
gr_3 = result_df1[["State","Sales"]]
data_gr3 = gr_3.groupby(gr_3["State"]).sum()

gr_4 = result_df1[["State","Profit"]]
data_gr4 = gr_4.groupby(gr_4["State"]).sum()

data_c1 = pd.concat([data_gr3,data_gr4["Profit"]],axis=1)
data_c1
# Out:
#                     Sales      Profit
# State
# Alabama         19510.640   5786.8253
# Arkansas        11678.130   4008.6871
# Florida         89473.708  -3399.3017
# Georgia         49095.840  16250.0433
# Kentucky        36591.750  11199.6966
# Louisiana        9217.030   2196.1023
# Mississippi     10771.340   3172.9762
# North Carolina  55603.164  -7490.9122
# South Carolina   8481.710   1769.0566
# Tennessee       30661.873  -5341.6936
# Virginia        70636.720  18597.9504

# %%
data_c1.plot(kind='bar',figsize=(16, 6),ylabel="US Dollars",title="Statewise Sales and Profit (US-South)")
plt.show()

# %% [markdown]
# <b> From the above visualizations we can see our Sales and Profits are both very low in Arkansas, Lousiana, Mississippi and South Carolina so we should work on those states. Intersting thing is that in Florida, North Carolina and Tennessee, even though our sales are high, we incurred loss. </b>

# %% [markdown]
# <h4 style="color:crimson;"> <li> <B>Statewise Sales and Profit Data Analysis (US-Central)</B></li> </h4>

# %%
result_df2 = data[(data["Region"]=="Central")]

gr_5 = result_df2[["State","Sales"]]
data_gr5 = gr_5.groupby(gr_5["State"],as_index = True).sum()

gr_6 = result_df2[["State","Profit"]]
data_gr6 = gr_6.groupby(gr_6["State"],as_index = True).sum()

data_c2 = pd.concat([data_gr5,data_gr6["Profit"]],axis=1)
data_c2
# Out:
#                     Sales      Profit
# State
# Illinois       80162.5370 -12601.6500
# Indiana        53555.3600  18382.9363
# Iowa            4579.7600   1183.8119
# Kansas          2914.3100    836.4435
# Michigan       75879.6440  24428.0903
# Minnesota      29863.1500  10823.1874
# Missouri       22205.1500   6436.2105
# Nebraska        7464.9300   2037.0942
# North Dakota     919.9100    230.1497
# Oklahoma       19683.3900   4853.9560
# South Dakota    1315.5600    394.8283
# Texas         170124.5418 -25750.9833
# Wisconsin      32114.6100   8401.8004

# %%
data_c2.plot(kind='bar',figsize=(16, 6),ylabel="US Dollars",title="Statewise Sales and Profit (US-Central)")
plt.show()

# %% [markdown]
# <b> From the above visualizations we can see our Sales and Profits are both very low in Iowa, Kansas, Nebraska, North Dakota and South Dakota so we should work on those states. Interesting thing is that in Illinois, and Texas  even though our sales are high, we incurred loss. </b>

# %% [markdown]
# <h4 style="color:crimson;"> <li> <B>Citywise Sales and Profit Data Analysis (South and Central US)</B></li> </h4>

# %%
com_df = pd.concat([gr_4,gr_6],axis=0)
gr_com=com_df.groupby("State").sum()
options = []
for k in range(len(gr_com.values.reshape(-1))):
    if gr_com.values.reshape(-1)[k] < 4009:
        options.append(gr_com.index[k])       
rslt_df3 = data[data['State'].isin(options)]
gr_7= rslt_df3[["City","Sales"]]
data_gr7 = gr_7.groupby(gr_7["City"],as_index = True).sum()
sorted_gr7 = data_gr7.sort_values(by='Sales')

gr_8= rslt_df3[["City","Profit"]]
data_gr8 = gr_8.groupby(gr_8["City"],as_index = True).sum()
sorted_gr8 = data_gr8.sort_values(by='Profit')

data_com4 = pd.concat([sorted_gr7,sorted_gr8["Profit"]],axis=1)

# %% [markdown]
# <b>South and Central US Cities sorted by Sales (First 15, in ascending order)</b>

# %%
data_com4.sort_values(by='Sales').head(15)
# Out:
#                 Sales   Profit
# Abilene         1.392  -3.7584
# Jupiter         2.064   0.1548
# Pensacola       2.214  -1.4760
# Ormond Beach    2.808  -1.9656
# Springdale      4.300   1.4190
# Keller          6.000   2.1000
# Missouri City   6.370  -9.5550
# Deer Park       6.924 -10.3860
# Port Orange     7.824   2.9340
# Romeoville      8.952 -14.7708
# Iowa City       9.990   4.4955
# Oak Park       10.192   1.0192
# Baytown        10.368   3.6288
# Rock Hill      11.850   3.7920
# Chapel Hill    14.016   4.7304

# %% [markdown]
# <B> South and Central US Cities sorted by Profit (First 15, in ascending order) </B>

# %%
data_com4.sort_values(by='Profit').head(15)
# Out:
#                    Sales      Profit
# Houston       64441.2564 -10175.1755
# San Antonio   21843.5280  -7299.0502
# Chicago       48535.9770  -6648.3318
# Burlington    12738.7120  -5867.8555
# Dallas        20131.9322  -2846.5257
# Jacksonville  44713.1830  -2323.8350
# Aurora         7572.9680  -1894.7196
# Concord        5111.8440  -1788.6868
# Memphis        5942.3410  -1479.0400
# Round Rock     4854.0528  -1183.4313
# Knoxville      3928.1660  -1165.0755
# Miami          8673.0745  -1150.3704
# Rockford       3166.2280  -1149.5078
# Clarksville    2217.7300  -1055.3532
# Huntsville     6710.6168   -843.4264

# %%
sorted_gr7.head(20).plot(kind='bar',figsize=(9, 6),color='crimson', title="Citywise Graph (Minimum Sales among Central and South US cities)",ylabel="Sales")
sorted_gr8.head(20).plot(kind='bar',figsize=(9, 6),color='crimson', title="Citywise Graph (Minimum Profit among Central and South US cities)",ylabel="Profit")
plt.show()

# %%
loss = 0 
for p in sorted_gr8["Profit"].values:
    if p <0:
        loss += 1
print(loss)
# Out:
# 89

# %% [markdown]
# <br><li><b> We incurred losses in 89 cities in the following states of South or Central US:</b></li><b> Iowa, Kansas, Nebraska, North Dakota, South Dakota, Illinois, Texas, Arkansas, Lousiana, Mississippi, South Carolina, Florida, North Carolina, Tennessee.</b><br><br><b><li> Least Sales are from following cities:</li> Abilene, Keller, MissouriCity, Deer Park, Romeoville, Iowa City, Baytown, Arlington Heights, Grand Island, Portage et cetera.<br></b></li><br><b><li> The cities where we incurred most losses are:</li><b> Houston, San Antonio, Chicago, Dallas, Aurora, Round Rock, Rockford, Huntsville, Oswego, Waco.<b>

# %% [markdown]
# <h4 style="color:crimson;"> <li> <B>Some other analysis</B></li> </h4>

# %%
data.pivot_table(values='Profit', index= 'Segment', columns= 'Discount',aggfunc= 'median')
# Out:
# Discount         0.00     0.10      0.15    0.20     0.30     0.32      0.40  \
# Segment
# Consumer     16.14600  62.0390   5.12940  6.0433 -26.0562 -30.0980 -47.21360
# Corporate    16.35285  46.7908  26.27735  6.7068 -28.2240 -59.0606 -87.27495
# Home Office  15.45460  37.2300  16.79860  7.2576 -18.2220 -57.3234 -49.71900
#
# Discount          0.45      0.50     0.60    0.70     0.80
# Segment
# Consumer    -135.68145 -175.2600 -14.1323 -8.7276 -13.7175
# Corporate   -255.58750 -120.5130 -10.4196 -8.9796 -16.7130
# Home Office -175.14690 -237.8425 -14.2290 -9.7608 -14.0328

# %%
data.pivot_table(values='Profit', index= 'Segment', columns= 'Discount', aggfunc= 'mean')
# Out:
# Discount          0.00       0.10       0.15       0.20       0.30  \
# Segment
# Consumer     64.281062  93.630090  15.744638  22.439654 -48.018291
# Corporate    71.717580  99.802956  49.282143  23.173335 -46.241380
# Home Office  67.079919  97.234865  30.271889  34.783007 -37.834059
#
# Discount           0.32        0.40        0.45        0.50       0.60  \
# Segment
# Consumer    -102.708631  -93.462041 -216.651900 -253.572181 -38.639822
# Corporate    -82.702010 -132.003562 -280.968633 -388.164788 -40.623326
# Home Office  -57.226350 -119.900858 -175.146900 -377.121333 -60.039948
#
# Discount           0.70        0.80
# Segment
# Consumer    -106.962433 -115.213404
# Corporate    -68.023771  -97.869076
# Home Office -115.479956  -62.509202

# %% [markdown]
# <b>From the above tables we can see that either (>20%) discount effects in loss, or storerunners sell products in (>20%) discounted price when their profits are not good enough or negative. </b>

# %%
gr_9 = data.groupby(["Category"])[['Profit','Sales']].agg('sum')
gr_9.plot(kind='bar',ylabel="US Dollars",title="Category wise Profit and Sales")
plt.show()

# %%
options2 = ['Florida','North Carolina', 'Texas', 'Tennessee','Illinois']
rslt_df_ = data[data['State'].isin(options2)]
gr_10 = rslt_df_.groupby(["State","Category"])[['Profit','Sales',"Category"]].agg('sum')
gr_10.plot(kind='bar',ylabel="US Dollars",title="Category wise Profit and Sales in high sales low profit states",figsize=(15,6))
plt.show()

# %% [markdown]
# <li><b> Even though previously we saw that Technology related order are least, it is now evident now most of our Profit and Sales are from them. So we should make our technology section stronger for even more profit. </b></li>

# %% [markdown]
# <li><b> In the sates like Florida,North Carolina, Texas, Tennessee, Illinois where are our Sales are high but still we incurred loss, we observe that selling Furnitures and office suplies are not really profitable where as selling Technology related items are profitable most of the time.</b></li>

# %% [markdown]
# <h2 style="color:purple;"><B>Conclusions</B> </h2>

# %% [markdown]
# <li><b> Our Sales from corporetes and home-offices are low, we may campaign or targeted advertisement to attract them. Also, gathering further informations might be helpful for further investigation. </b></li><br><li><b> Even though order counts for technology products are low, most of our Sales and Profit comes from them. So we should further strengthen our tech section. </b></li><br><li><b> Our Sales are weak in Central and South US, let us narrow down on these regions. </b></li><br><li><b>  Our Sales and Profits are both very low in Arkansas, Lousiana, Mississippi, South Carolina, Iowa, Kansas, Nebraska, North Dakota and South Dakota so we should gather more informations on number of returns, supply chain, finance for better understanding in those states. </b></li><br><li><b> Intersting thing is that in Florida, North Carolina and Tennessee, Illinois, and Texas, even though our sales are high, we incurred loss. Hence, more data regarding demand, supply chain, number of returns, finance in needed for funther investigation. </b></li><br><li><b> Our sales are really lackluster in cities like Abilene, Keller, MissouriCity, Deer Park, Romeoville, Iowa City, Baytown, Arlington Heights, Grand Island, Portage et cetera, Some advertisement should work. </b></li><br><li><b> We suffered heavy loss in cities like Houston, San Antonio, Chicago, Dallas, Aurora, Round Rock, Rockford, Huntsville, Oswego, Waco, We might dig deeper into details of sales affecting phenomena at these places. </b></li><br><li><b> We should stick with 0-20% discount, more discounts are not really profitable.</b></li>
